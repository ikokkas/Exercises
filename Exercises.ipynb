# %%
# import the pandas library as "pd"

import pandas as pd

# %%
# read the titanic.csv file and create a dataframe from it using the appropriade method of pandas library

my_df = pd.read_csv("titanic.csv")

# %%
#methods - are followed by parenthesis

# Quick exploration for the dataset, .head() returns the first 5 rows by default.

my_df.head()


#discplays names of columns, the data types they contain and where the have any missing values.

homelessness.info()

# compute some summary statistics for numerical columns like mean and median
# count is the number of non-missing values in each column

homelessness.describe()

# attributes - are not followed by parenthesis

# returns a tuple that holds the number of rows followed by the number of columns.
homelessness.shape

# represent the data values in a 2-dimensional NumPy array.
homelessness.values

# represent column names in a list
homelessness.columns

# show the row numbers or row names
homelessness.index
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      51 non-null     int64
#  1   region          51 non-null     object
#  2   state           51 non-null     object
#  3   individuals     51 non-null     float64
#  4   family_members  51 non-null     float64
#  5   state_pop       51 non-null     int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 2.5+ KB
# RangeIndex(start=0, stop=51, step=1)

# %% [markdown]
# # Inspecting a DataFrame
# When you get a new DataFrame to work with, the first thing you need to do is explore it and see what it contains. There are several useful methods and attributes for this.
#
# - .head() returns the first few rows (the “head” of the DataFrame).
# - .info() shows information on each of the columns, such as the data type and number of missing values.
# - .shape returns the number of rows and columns of the DataFrame.
# - .describe() calculates a few summary statistics for each column.
#
# homelessness is a DataFrame containing estimates of homelessness in each U.S. state in 2018. The individual column is the number of homeless individuals not part of a family with children. The family_members column is the number of homeless individuals part of a family with children. The state_pop column is the state's total population

# %%
# Print the column index of homelessness

print (my_df.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# Print the row index of homelessness

print (my_df.index)
# Out:
# RangeIndex(start=0, stop=892, step=1)

# %%
# Print some values of titanic dataframe

print (my_df.values)
# Out:
# [[0.0 3.0 'male' ... 'Southampton' 'no' False]
#  [1.0 1.0 'female' ... 'Cherbourg' 'yes' False]
#  [1.0 3.0 'female' ... 'Southampton' 'yes' True]
#  ...
#  [0.0 3.0 'female' ... 'Southampton' 'no' False]
#  [1.0 1.0 'male' ... 'Cherbourg' 'yes' True]
#  [0.0 3.0 'male' ... 'Queenstown' 'no' True]]

# %%
# Print the head of the titanic dataframe and check how many rows of this dataframe are printed

print (my_df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0       0.0     3.0    male  22.0      1      0   7.2500        S  Third
# 1       1.0     1.0  female  38.0      1      0  71.2833        C  First
# 2       1.0     3.0  female  26.0      0      0   7.9250        S  Third
# 3       1.0     1.0  female  35.0      1      0  53.1000        S  First
# 4       0.0     3.0    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Print the first 10 rows of the titanic dataframe

print (my_df.head(10))
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0       0.0     3.0    male  22.0      1      0   7.2500        S   Third
# 1       1.0     1.0  female  38.0      1      0  71.2833        C   First
# 2       1.0     3.0  female  26.0      0      0   7.9250        S   Third
# 3       1.0     1.0  female  35.0      1      0  53.1000        S   First
# 4       0.0     3.0    male  35.0      0      0   8.0500        S   Third
# 5       0.0     3.0    male   NaN      0      0   8.4583        Q   Third
# 6       0.0     1.0    male  54.0      0      0  51.8625        S   First
# 7       0.0     3.0    male   2.0      3      1  21.0750        S   Third
# 8       1.0     3.0  female  27.0      0      2  11.1333        S   Third
# 9       1.0     2.0  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
# Print the first 22 rows of the titanic dataframe

print (my_df.head(22))
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0        0.0     3.0    male  22.0      1      0   7.2500        S   Third
# 1        1.0     1.0  female  38.0      1      0  71.2833        C   First
# 2        1.0     3.0  female  26.0      0      0   7.9250        S   Third
# 3        1.0     1.0  female  35.0      1      0  53.1000        S   First
# 4        0.0     3.0    male  35.0      0      0   8.0500        S   Third
# 5        0.0     3.0    male   NaN      0      0   8.4583        Q   Third
# 6        0.0     1.0    male  54.0      0      0  51.8625        S   First
# 7        0.0     3.0    male   2.0      3      1  21.0750        S   Third
# 8        1.0     3.0  female  27.0      0      2  11.1333        S   Third
# 9        1.0     2.0  female  14.0      1      0  30.0708        C  Second
# 10       1.0     3.0  female   4.0      1      1  16.7000        S   Third
# ...

# %%
# Print the last 5 rows of the titanic dataframe

print (my_df.tail())
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 887       0.0     2.0    male  27.0      0      0  13.00        S  Second
# 888       1.0     1.0  female  19.0      0      0  30.00        S   First
# 889       0.0     3.0  female   NaN      1      2  23.45        S   Third
# 890       1.0     1.0    male  26.0      0      0  30.00        C   First
# 891       0.0     3.0    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 887    man        True  NaN  Southampton    no   True
# 888  woman       False    B  Southampton   yes   True
# 889  woman       False  NaN  Southampton    no  False
# 890    man        True    C    Cherbourg   yes   True
# 891    man        True  NaN   Queenstown    no   True

# %%
# Print the last 10 rows of the titanic dataframe

print (my_df.tail(10))
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 882       0.0     3.0    male  33.0      0      0   7.8958        S   Third
# 883       0.0     3.0  female  22.0      0      0  10.5167        S   Third
# 884       0.0     2.0    male  28.0      0      0  10.5000        S  Second
# 885       0.0     3.0    male  25.0      0      0   7.0500        S   Third
# 886       0.0     3.0  female  39.0      0      5  29.1250        Q   Third
# 887       0.0     2.0    male  27.0      0      0  13.0000        S  Second
# 888       1.0     1.0  female  19.0      0      0  30.0000        S   First
# 889       0.0     3.0  female   NaN      1      2  23.4500        S   Third
# 890       1.0     1.0    male  26.0      0      0  30.0000        C   First
# 891       0.0     3.0    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 882    man        True  NaN  Southampton    no   True
# ...

# %%
# Print the last 22 rows of the titanic dataframe

print (my_df.tail(22))
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 870       1.0     3.0    male   4.0      1      1  11.1333        S   Third
# 871       0.0     3.0    male  26.0      0      0   7.8958        S   Third
# 872       1.0     1.0  female  47.0      1      1  52.5542        S   First
# 873       0.0     1.0    male  33.0      0      0   5.0000        S   First
# 874       0.0     3.0    male  47.0      0      0   9.0000        S   Third
# 875       1.0     2.0  female  28.0      1      0  24.0000        C  Second
# 876       1.0     3.0  female  15.0      0      0   7.2250        C   Third
# 877       0.0     3.0    male  20.0      0      0   9.8458        S   Third
# 878       0.0     3.0    male  19.0      0      0   7.8958        S   Third
# 879       0.0     3.0    male   NaN      0      0   7.8958        S   Third
# 880       1.0     1.0  female  56.0      0      1  83.1583        C   First
# ...

# %%
# How many Non-null values has each column and which is the Datatype for each one?

print(my_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    float64
#  1   pclass       891 non-null    float64
#  2   sex          891 non-null    object
#  3   age          715 non-null    float64
#  4   sibsp        892 non-null    int64
#  5   parch        892 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     890 non-null    object
#  8   class        892 non-null    object
#  9   who          892 non-null    object
#  10  adult_male   892 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        892 non-null    object
#  14  alone        891 non-null    object
# dtypes: bool(1), float64(4), int64(2), object(8)
# memory usage: 98.6+ KB
# None

# %%
# How many rows and columns has the titanic dataframe?

print(my_df.shape)
# Out:
# (892, 15)

# %%
# compute some summary statistics(mean, standard deviation, min-max values) and the number of non-missing values in each column

print(my_df.describe())
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  715.000000  892.000000  892.000000  891.000000
# mean     0.383838    2.309764   29.700937    0.522422    0.381166   32.183136
# std      0.486592    0.834983   14.516403    1.102264    0.805706   49.699809
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.250000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # Sorting and subsetting

# %%
# Print the head of the titanic dataframe in a dataframe format

my_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0       0.0     3.0    male  22.0      1      0   7.2500        S  Third
# 1       1.0     1.0  female  38.0      1      0  71.2833        C  First
# 2       1.0     3.0  female  26.0      0      0   7.9250        S  Third
# 3       1.0     1.0  female  35.0      1      0  53.1000        S  First
# 4       0.0     3.0    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Sorting

# %%
# sort my_df on the 'class' column in ascending order

my_df.sort_values("class")
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 445       1.0     1.0    male   4.0      0      2   81.8583        S  First
# 779       1.0     1.0  female  43.0      0      1  211.3375        S  First
# 177       0.0     1.0  female  50.0      0      0   28.7125        C  First
# 660       1.0     1.0    male  50.0      2      0  133.6500        S  First
# 662       0.0     1.0    male  47.0      0      0   25.5875        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 379       0.0     3.0    male  19.0      0      0    7.7750        S  Third
# 381       1.0     3.0  female   1.0      0      2   15.7417        C  Third
# 382       0.0     3.0    male  32.0      0      0    7.9250        S  Third
# 371       0.0     3.0    male  18.0      1      0    6.4958        S  Third
# 891       0.0     3.0    male  32.0      0      0    7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# sort my_df on the 'class' column in descending order

my_df.sort_values("class", ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0.0     3.0    male  22.0      1      0    7.2500        S  Third
# 514       0.0     3.0    male  24.0      0      0    7.4958        S  Third
# 501       0.0     3.0  female  21.0      0      0    7.7500        Q  Third
# 502       0.0     3.0  female   NaN      0      0    7.6292        Q  Third
# 503       0.0     3.0  female  37.0      0      0    9.5875        S  Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 712       1.0     1.0    male  48.0      1      0   52.0000        S  First
# 102       0.0     1.0    male  21.0      0      1   77.2875        S  First
# 467       0.0     1.0    male  56.0      0      0   26.5500        S  First
# 716       1.0     1.0  female  38.0      0      0  227.5250        C  First
# 602       0.0     1.0    male   NaN      0      0   42.4000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# sort my_df on the 'class' column and on the 'embark_town' column

my_df.sort_values(["class", "embark_town"])
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 1         1.0     1.0  female  38.00      1      0   71.2833        C  First
# 30        0.0     1.0    male  40.00      0      0   27.7208        C  First
# 31        1.0     1.0  female    NaN      1      0  146.5208        C  First
# 34        0.0     1.0    male  28.00      1      0   82.1708        C  First
# 52        1.0     1.0  female  49.00      1      0   76.7292        C  First
# ..        ...     ...     ...    ...    ...    ...       ...      ...    ...
# 882       0.0     3.0    male  33.00      0      0    7.8958        S  Third
# 883       0.0     3.0  female  22.00      0      0   10.5167        S  Third
# 885       0.0     3.0    male  25.00      0      0    7.0500        S  Third
# 889       0.0     3.0  female    NaN      1      2   23.4500        S  Third
# 804       1.0     3.0    male   0.42      0      1    8.5167        C  Third
#
# ...

# %%
# sort my_df on the 'class' column in descending order and on the 'embark_town' column in ascending order

my_df.sort_values(["class", "embark_town"], ascending=[False,True])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 19        1.0     3.0  female   NaN      0      0   7.2250        C  Third
# 26        0.0     3.0    male   NaN      0      0   7.2250        C  Third
# 36        1.0     3.0    male   NaN      0      0   7.2292        C  Third
# 39        1.0     3.0  female  14.0      1      0  11.2417        C  Third
# 42        0.0     3.0    male   NaN      0      0   7.8958        C  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 872       1.0     1.0  female  47.0      1      1  52.5542        S  First
# 873       0.0     1.0    male  33.0      0      0   5.0000        S  First
# 888       1.0     1.0  female  19.0      0      0  30.0000        S  First
# 61        1.0     1.0  female  38.0      0      0  80.0000      NaN  First
# 830       1.0     1.0  female  62.0      0      0  80.0000      NaN  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# sort my_df on the 'class' column in descending order and on the 'embark_town' column in ascending order

my_df.sort_values(["class", "embark_town"], ascending=[False,True])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 19        1.0     3.0  female   NaN      0      0   7.2250        C  Third
# 26        0.0     3.0    male   NaN      0      0   7.2250        C  Third
# 36        1.0     3.0    male   NaN      0      0   7.2292        C  Third
# 39        1.0     3.0  female  14.0      1      0  11.2417        C  Third
# 42        0.0     3.0    male   NaN      0      0   7.8958        C  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 872       1.0     1.0  female  47.0      1      1  52.5542        S  First
# 873       0.0     1.0    male  33.0      0      0   5.0000        S  First
# 888       1.0     1.0  female  19.0      0      0  30.0000        S  First
# 61        1.0     1.0  female  38.0      0      0  80.0000      NaN  First
# 830       1.0     1.0  female  62.0      0      0  80.0000      NaN  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### Subsetting

# %%
# print a pandas series of True / False values based on the condition "fare" column values greater than 10

my_df["fare"] > 10
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 887     True
# 888     True
# 889     True
# 890     True
# 891    False
# Name: fare, Length: 892, dtype: bool

# %%
# subset the dataframe based on the condition where "fare" value is greater than 10

my_df[my_df["fare"] > 10]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1         1.0     1.0  female  38.0      1      0  71.2833        C   First
# 3         1.0     1.0  female  35.0      1      0  53.1000        S   First
# 6         0.0     1.0    male  54.0      0      0  51.8625        S   First
# 7         0.0     3.0    male   2.0      3      1  21.0750        S   Third
# 8         1.0     3.0  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886       0.0     3.0  female  39.0      0      5  29.1250        Q   Third
# 887       0.0     2.0    male  27.0      0      0  13.0000        S  Second
# 888       1.0     1.0  female  19.0      0      0  30.0000        S   First
# 889       0.0     3.0  female   NaN      1      2  23.4500        S   Third
# 890       1.0     1.0    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# subset the dataframe based on the condition where "fare" value is less than 20

my_df[my_df["fare"] > 20]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1         1.0     1.0  female  38.0      1      0  71.2833        C   First
# 3         1.0     1.0  female  35.0      1      0  53.1000        S   First
# 6         0.0     1.0    male  54.0      0      0  51.8625        S   First
# 7         0.0     3.0    male   2.0      3      1  21.0750        S   Third
# 9         1.0     2.0  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 881       1.0     2.0  female  25.0      0      1  26.0000        S  Second
# 886       0.0     3.0  female  39.0      0      5  29.1250        Q   Third
# 888       1.0     1.0  female  19.0      0      0  30.0000        S   First
# 889       0.0     3.0  female   NaN      1      2  23.4500        S   Third
# 890       1.0     1.0    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# subset the dataframe based on the condition where "who" column value is 'woman'

my_df[my_df["who"] == "woman"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1         1.0     1.0  female  38.0      1      0  71.2833        C   First
# 2         1.0     3.0  female  26.0      0      0   7.9250        S   Third
# 3         1.0     1.0  female  35.0      1      0  53.1000        S   First
# 8         1.0     3.0  female  27.0      0      2  11.1333        S   Third
# 11        1.0     1.0  female  58.0      0      0      NaN        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 881       1.0     2.0  female  25.0      0      1  26.0000        S  Second
# 883       0.0     3.0  female  22.0      0      0  10.5167        S   Third
# 886       0.0     3.0  female  39.0      0      5  29.1250        Q   Third
# 888       1.0     1.0  female  19.0      0      0  30.0000        S   First
# 889       0.0     3.0  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# subset the dataframe based on the condition where "who" column value is 'woman' or 'child' 

my_df[(my_df["who"] == "woman") | (my_df["who"] == "child")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1         1.0     1.0  female  38.0      1      0  71.2833        C   First
# 2         1.0     3.0  female  26.0      0      0   7.9250        S   Third
# 3         1.0     1.0  female  35.0      1      0  53.1000        S   First
# 7         0.0     3.0    male   2.0      3      1  21.0750        S   Third
# 8         1.0     3.0  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 881       1.0     2.0  female  25.0      0      1  26.0000        S  Second
# 883       0.0     3.0  female  22.0      0      0  10.5167        S   Third
# 886       0.0     3.0  female  39.0      0      5  29.1250        Q   Third
# 888       1.0     1.0  female  19.0      0      0  30.0000        S   First
# 889       0.0     3.0  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# subset the dataframe based on the condition where "embark_town" column value is 'Southampton' and the "who" column value is 'man' 

my_df[(my_df["embark_town"] == "Southampton") & (my_df["who"] == "man")]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0         0.0     3.0  male  22.0      1      0   7.2500        S   Third
# 4         0.0     3.0  male  35.0      0      0   8.0500        S   Third
# 6         0.0     1.0  male  54.0      0      0  51.8625        S   First
# 12        0.0     3.0  male  20.0      0      0   8.0500        S   Third
# 13        0.0     3.0  male  39.0      1      5  31.2750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 879       0.0     3.0  male   NaN      0      0   7.8958        S   Third
# 882       0.0     3.0  male  33.0      0      0   7.8958        S   Third
# 884       0.0     2.0  male  28.0      0      0  10.5000        S  Second
# 885       0.0     3.0  male  25.0      0      0   7.0500        S   Third
# 887       0.0     2.0  male  27.0      0      0  13.0000        S  Second
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
# subset the dataframe to show only rows where embark_town is in "Southampton" or "Cherbourg"

my_df[my_df["embark_town"].isin(["Southampton","Cherbourg"])]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0.0     3.0    male  22.0      1      0   7.2500        S   Third
# 1         1.0     1.0  female  38.0      1      0  71.2833        C   First
# 2         1.0     3.0  female  26.0      0      0   7.9250        S   Third
# 3         1.0     1.0  female  35.0      1      0  53.1000        S   First
# 4         0.0     3.0    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885       0.0     3.0    male  25.0      0      0   7.0500        S   Third
# 887       0.0     2.0    male  27.0      0      0  13.0000        S  Second
# 888       1.0     1.0  female  19.0      0      0  30.0000        S   First
# 889       0.0     3.0  female   NaN      1      2  23.4500        S   Third
# 890       1.0     1.0    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Out:
# embark_town
# Cherbourg      1
# Queenstown     1
# Southampton    1
# Name: embark_town, dtype: int64

# %% [markdown]
# # Aggregation exercises

# %%
startup_df = pd.read_csv("50_Startups.csv")

startup_df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# create a new ID column

#startup_df.columns[1] = "ID"

startup_df["ID"] = startup_df.index +1

startup_df = startup_df[["ID", "R&D Spend", "Administration", "Marketing Spend", "State", "Profit"]]

startup_df.head()
# Out:
#    ID  R&D Spend  Administration  Marketing Spend       State     Profit
# 0   1  165349.20       136897.80        471784.10    New York  192261.83
# 1   2  162597.70       151377.59        443898.53  California  191792.06
# 2   3  153441.51       101145.55        407934.54     Florida  191050.39
# 3   4  144372.41       118671.85        383199.62    New York  182901.99
# 4   5  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# How many rows and columns has the titanic dataframe?

print(startup_df.shape)
# Out:
# (53, 6)

# %%
# As seen, there are more than 50 startups in this dataset
# obviously there cannot be 2 or more startups with the same profit, state, and Marketing Spend

# drop the duplicate rows, if any, based on these 3 aforementioned columns

startup_df = startup_df.drop_duplicates(["Profit", "Marketing Spend", "State"])

# %%
# Now check again the shape of the startup dataframe to be sure that there are only 50 unique startups

print(startup_df.shape)
# Out:
# (50, 6)

# %%
# create a new column "Total_Spend" which will be the sum of the R&D Spend, Administration and Marketing Spend

startup_df["Total_Spend"] = startup_df["R&D Spend"] + startup_df["Administration"] + startup_df["Marketing Spend"]

startup_df.head()
# Out:
#    ID  R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   1  165349.20       136897.80        471784.10    New York  192261.83
# 1   2  162597.70       151377.59        443898.53  California  191792.06
# 2   3  153441.51       101145.55        407934.54     Florida  191050.39
# 3   4  144372.41       118671.85        383199.62    New York  182901.99
# 4   5  142107.34        91391.77        366168.42     Florida  166187.94
#
#    Total_Spend
# 0    774031.10
# 1    757873.82
# 2    662521.60
# 3    646243.88
# 4    599667.53

# %%
# Sort the dataset by profit in ascending order

startup_df.sort_values("Profit", ascending=True)
# Out:
#     ID  R&D Spend  Administration  Marketing Spend       State     Profit  \
# 49  50       0.00       116983.80         45173.06  California   14681.40
# 48  49     542.05        51743.15             0.00    New York   35673.41
# 47  48       0.00       135426.92             0.00  California   42559.73
# 46  47    1315.46       115816.21        297114.46     Florida   49490.75
# 45  46    1000.23       124153.04          1903.93    New York   64926.08
# 44  45   22177.74       154806.14         28334.72  California   65200.33
# 43  44   15505.73       127382.30         35534.17    New York   69758.98
# 42  43   23640.93        96189.63        148001.11  California   71498.49
# 41  42   27892.92        84710.77        164470.71     Florida   77798.83
# 40  41   28754.33       118546.05        172795.67  California   78239.91
# 39  40   38558.51        82982.09        174999.30  California   81005.76
# 38  39   20229.59        65947.93        185265.10    New York   81229.06
# ...

# %%
# which are the 3 companies that spend the most money on R&D

startup_df.sort_values("R&D Spend", ascending=False).head(3)
# Out:
#    ID  R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   1  165349.20       136897.80        471784.10    New York  192261.83
# 1   2  162597.70       151377.59        443898.53  California  191792.06
# 2   3  153441.51       101145.55        407934.54     Florida  191050.39
#
#    Total_Spend
# 0    774031.10
# 1    757873.82
# 2    662521.60

# %%
# which are the 6 companies that spend the less money on Administration

startup_df.sort_values("Administration", ascending=True).head(6)
# Out:
#     ID  R&D Spend  Administration  Marketing Spend       State    Profit  \
# 37  38   44069.95        51283.14        197029.42  California  89949.14
# 48  49     542.05        51743.15             0.00    New York  35673.41
# 38  39   20229.59        65947.93        185265.10    New York  81229.06
# 39  40   38558.51        82982.09        174999.30  California  81005.76
# 41  42   27892.92        84710.77        164470.71     Florida  77798.83
# 35  36   46014.02        85047.44        205517.64    New York  96479.51
#
#     Total_Spend
# 37    292382.51
# 48     52285.20
# 38    271442.62
# 39    296539.90
# 41    277074.40
# 35    336579.10

# %%
# create a new column "ROI" calculated from "Profit" / "Total_Spend" columns

startup_df["ROI"] = startup_df["Profit"] / startup_df["Total_Spend"]

# %%
# find out which are the 10 companies that have the highest "ROI" ratio

startup_df.sort_values("ROI", ascending=False).head(10)
# Out:
#     ID  R&D Spend  Administration  Marketing Spend       State     Profit  \
# 48  49     542.05        51743.15             0.00    New York   35673.41
# 19  20   86419.70       153514.11             0.00    New York  122776.86
# 45  46    1000.23       124153.04          1903.93    New York   64926.08
# 32  33   63408.86       129219.61         46085.25  California   97427.84
# 43  44   15505.73       127382.30         35534.17    New York   69758.98
# 6    7  134615.46       147198.87        127716.82  California  156122.51
# 30  31   61994.48       115641.28         91131.24     Florida   99937.59
# 24  25   77044.01        99281.34        140574.81    New York  108552.04
# 10  11  101913.08       110594.11        229160.95     Florida  146121.95
# 11  12  100671.96        91790.61        249744.55  California  144259.40
#
#     Total_Spend       ROI
# 48     52285.20  0.682285
# 19    239933.81  0.511711
# 45    127057.20  0.510999
# 32    238713.72  0.408137
# ...

# %%
# Calculate the average R&D Spend made from these startups

startup_df["R&D Spend"].mean()
# Out:
# 73721.61559999999

# %%
# Calculate the max Profit made from these startups

startup_df["R&D Spend"].max()
# Out:
# 165349.2

# %%
# Calculate the min Administration made from these startups

startup_df["Administration"].min()
# Out:
# 51283.14

# %%
# Sort the dataset so that only startups with higher R&D Spend than the average R&D Spend are shown

startup_df[startup_df["R&D Spend"] > startup_df["R&D Spend"].mean()]
# Out:
#     ID  R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0    1  165349.20       136897.80        471784.10    New York  192261.83
# 1    2  162597.70       151377.59        443898.53  California  191792.06
# 2    3  153441.51       101145.55        407934.54     Florida  191050.39
# 3    4  144372.41       118671.85        383199.62    New York  182901.99
# 4    5  142107.34        91391.77        366168.42     Florida  166187.94
# 5    6  131876.90        99814.71        362861.36    New York  156991.12
# 6    7  134615.46       147198.87        127716.82  California  156122.51
# 7    8  130298.13       145530.06        323876.68     Florida  155752.60
# 8    9  120542.52       148718.95        311613.29    New York  152211.77
# 9   10  123334.88       108679.17        304981.62  California  149759.96
# 10  11  101913.08       110594.11        229160.95     Florida  146121.95
# 11  12  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
# Filter the dataset so that only data for the startup with the minimum "Administration" spend are shown

startup_df[startup_df["Administration"] == startup_df["Administration"].min()]
# Out:
#     ID  R&D Spend  Administration  Marketing Spend       State    Profit  \
# 37  38   44069.95        51283.14        197029.42  California  89949.14
#
#     Total_Spend       ROI
# 37    292382.51  0.307642

# %%
# Filter the dataset so that only data for the startup with the maximum "R&D Spend" spend are shown

startup_df[startup_df["R&D Spend"] == startup_df["R&D Spend"].max()]
# Out:
#    ID  R&D Spend  Administration  Marketing Spend     State     Profit  \
# 0   1   165349.2        136897.8         471784.1  New York  192261.83
#
#    Total_Spend      ROI
# 0     774031.1  0.24839

# %%
# Find out how many startups are located to each different "State"

startup_df["State"].value_counts()
# Out:
# New York      20
# California    17
# Florida       16
# Name: State, dtype: int64

# %%
# Get the proportion of states and sort them in descending order

startup_df["State"].value_counts(sort=True, normalize=True)
# Out:
# New York      0.377358
# California    0.320755
# Florida       0.301887
# Name: State, dtype: float64

# %%
# Which is the mean Administration spend for each different state?

startup_df.groupby("State")["Administration"].mean()
# Out:
# State
# California    120746.507059
# Florida       121768.897500
# New York      122360.472000
# Name: Administration, dtype: float64

# %%
# Which is the maximum R&D spend for each different state?

startup_df.groupby("State")["R&D Spend"].max()
# Out:
# State
# California    162597.70
# Florida       153441.51
# New York      165349.20
# Name: R&D Spend, dtype: float64

# %%
# Which is the min, max and total value of profit for each different state?

startup_df.groupby("State")["Profit"].agg([min, max, sum])
# Out:
#                  min        max         sum
# State
# California  14681.40  191792.06  1766387.98
# Florida     49490.75  191050.39  1900384.39
# New York    35673.41  192261.83  2271922.71

# %%
startup_df.groupby("State")[["R&D Spend", "Administration", "Marketing Spend"]].mean()
# Out:
#                R&D Spend  Administration  Marketing Spend
# State
# California  64657.674118   120746.507059    182540.929412
# Florida     80724.016250   121768.897500    247323.551250
# New York    76054.408000   122360.472000    209450.754500

# %%
startup_df.groupby("State")[["R&D Spend", "Administration", "Marketing Spend"]].agg(["mean",sum])
# Out:
#                R&D Spend             Administration              \
#                     mean         sum           mean         sum
# State
# California  64657.674118  1099180.46  120746.507059  2052690.62
# Florida     80724.016250  1291584.26  121768.897500  1948302.36
# New York    76054.408000  1521088.16  122360.472000  2447209.44
#
#            Marketing Spend
#                       mean         sum
# State
# California   182540.929412  3103195.80
# Florida      247323.551250  3957176.82
# New York     209450.754500  4189015.09
